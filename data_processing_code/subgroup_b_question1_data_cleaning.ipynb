# %% [markdown]
# # Cleaning Wait Times Data

# %%
import os
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('../data/uss_wait_times.csv')

df = df.drop(columns=['Unnamed: 0'])
df = df.rename(columns={'Ride': 'ride', 'Date/Time': 'datetime', 'Wait Time': 'waittime'})
df['datetime'] = pd.to_datetime(df['datetime'])

# Filter for entries from Q1 2023 to Q2 2024
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 6, 30, 23, 59, 59)

df = df[(df['datetime'] >= start_date) & (df['datetime'] <= end_date)].sort_values(by='datetime')

# %%
# Park opens at 10am and typically closes at 9pm. We look into the entries recorded before 10am and after 10pm (to account for an hour's buffer after the park's closing time).
df_early = df[(df['datetime'].dt.hour < 10) & (df['waittime'] > 0)].groupby([df['datetime'].dt.month, df['datetime'].dt.day]).agg({'waittime': 'mean'})
df_late = df[(df['datetime'].dt.hour >
              21) & (df['waittime'] > 0)].groupby([df['datetime'].dt.month, df['datetime'].dt.day]).agg({'waittime': 'mean'})

print(df_early)
print(df_late)

# %%
# Rides are open during Halloween Horror Night, which occurred between 29 Sept to 4 Nov 2023.
# As such, we keep "early" and "late" entries in the df, and exclude the rest, which may have been included due to errors.
df_waittimes = df[((df['datetime'].dt.hour >= 10) & (df['datetime'].dt.hour <= 21)) |
        ((df['datetime'].dt.hour < 10) & (df['waittime'] > 0) & (df['datetime'].dt.month != 2)) |
        ((df['datetime'].dt.hour > 21) & (df['waittime'] > 0) & (df['datetime'].dt.month == 9)) |
        ((df['datetime'].dt.hour > 21) & (df['waittime'] > 0) & (df['datetime'].dt.month == 10))]

# # Save the filtered data to CSV
# df_waittimes.to_csv("/content/waittimes_full.csv", index=False)

# %% [markdown]
# # Extracting Weather Data from Data.gov.sg API
# URL: https://data.gov.sg/datasets/d_ce2eb1e307bda31993c533285834ef2b/view#tag/default/GET/twenty-four-hr-forecast

# %%
import requests
import datetime
import csv
import time

# %%
def is_raining(forecast_text):
    # Define keywords that indicate rain
    rain_keywords = ['Rain', 'Showers', 'Thundery Showers', 'Heavy Showers', 'Light Showers']
    return 1 if any(keyword in forecast_text for keyword in rain_keywords) else 0

def get_weather_data_south_region(start_date, end_date, output_file):
    url = "https://api-open.data.gov.sg/v2/real-time/api/twenty-four-hr-forecast"
    current_datetime = datetime.datetime.combine(start_date, datetime.time(0, 0))


    with open(output_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['datetime', 'forecast', 'mean temperature (°C)', 'is raining'])

        while current_datetime <= datetime.datetime.combine(end_date, datetime.time(23, 59)):
            datetime_str = current_datetime.strftime("%Y-%m-%dT%H:%M:%S")
            params = {'date': datetime_str}

            try:
                response = requests.get(url, params=params)

                if response.status_code == 200:
                    data = response.json()
                    record_found = False
                    for record in data['data']['records']:
                        general_forecast = record.get('general', {})
                        temperature = general_forecast.get('temperature', {})
                        low_temp = temperature.get('low', None)
                        high_temp = temperature.get('high', None)

                        mean_temp = (low_temp + high_temp) / 2 if low_temp and high_temp else 'N/A'

                        for period in record.get('periods', []):
                            if 'south' in period['regions'] and not record_found:
                                weather_info = period['regions']['south']
                                forecast_text = weather_info['text']
                                raining = is_raining(forecast_text)

                                writer.writerow([datetime_str, forecast_text, mean_temp, raining])
                                record_found = True  # Ensure we only write one record per interval

                    if not record_found:

                        writer.writerow([datetime_str, 'N/A', 'N/A', 0])

                else:
                    raise Exception(f"Failed with status code {response.status_code}")

            except Exception as e:
                print(f"Failed to retrieve data for {datetime_str}, using 'N/A' values: {str(e)}")
                writer.writerow([datetime_str, 'N/A', 'N/A', 0])

            current_datetime += datetime.timedelta(minutes=30)


start_date = datetime.date(2023, 1, 1)
end_date = datetime.date(2024, 6, 30)


output_file = '../data/raw/sentosa_region_weather_data.csv'

get_weather_data_south_region(start_date, end_date, output_file)

print(f"Weather data saved to {output_file}")
# Out:
# Failed to retrieve data for 2023-01-02T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-02T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-03T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-04T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-05T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-06T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-07T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-08T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-09T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-01-10T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-19T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-02-20T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-03-29T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2023-04-07T18:00:00, using 'N/A' values: Failed with status code 404
# ...
# Failed to retrieve data for 2024-03-07T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-07T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-08T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-09T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T16:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T17:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T17:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T18:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T18:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T19:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T19:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T20:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T20:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T21:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T21:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T22:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T22:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T23:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-10T23:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T00:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T00:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T01:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T01:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T02:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T02:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T03:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T03:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T04:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T04:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T05:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T05:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T06:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T06:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T07:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T07:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T11:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T12:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T12:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T13:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T13:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T14:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T14:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T15:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T15:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-03-11T16:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T08:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T08:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T09:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T09:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T10:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T10:30:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T11:00:00, using 'N/A' values: Failed with status code 404
# Failed to retrieve data for 2024-04-21T11:30:00, using 'N/A' values: Failed with status code 404
# Weather data saved to sentosa_region_weather_data.csv

# %%
import pandas as pd

waittimes = df_waittimes.copy()

waittimes.set_index('datetime', inplace=True)

average_wait_time = waittimes['waittime'].resample('30T').mean().reset_index()

average_wait_time.columns = ['datetime', 'average_waittime']
average_wait_time = average_wait_time[average_wait_time['average_waittime'] != 0]

print(average_wait_time)
# Out:
#                  datetime  average_waittime
# 2     2023-01-02 11:00:00          7.916667
# 3     2023-01-02 11:30:00         27.272727
# 4     2023-01-02 12:00:00         37.232143
# 5     2023-01-02 12:30:00         47.822581
# 6     2023-01-02 13:00:00         45.135135
# ...                   ...               ...
# 26173 2024-06-30 16:30:00         23.154762
# 26174 2024-06-30 17:00:00         22.440476
# 26175 2024-06-30 17:30:00         19.761905
# 26176 2024-06-30 18:00:00         14.464286
# 26177 2024-06-30 18:30:00         14.523810
#
# [22572 rows x 2 columns]
# <ipython-input-17-70a12a3984a3>:10: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   average_wait_time = waittimes['waittime'].resample('30T').mean().reset_index()

# %% [markdown]
# # Combining Wait Time and Weather Data

# %%
weather = pd.read_csv('../data/raw/sentosa_region_weather_data.csv', parse_dates=['datetime'])
combined=pd.merge(average_wait_time, weather, on='datetime', how='inner')

# %%
combined
combined.to_csv('../data/processed/uss_waittime_and_weather.csv', index=False)
